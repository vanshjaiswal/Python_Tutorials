# %% [markdown]
# # Variable: A programmers perspective

# %% [markdown]
# You are free to decide the name of your variable but it is always a good practice if you are taking the variable name which is self-explanatory and meaningful. This will enhance the readability of your code.

# %%
'''
a person Ram  Shyam have salary of 10000$ and expense of 2000$
and Shyam have salary of 20000$ and expenses are 3000$.

What is the total saving of the family at the end of month.


'''

# %%
a=10000
b=2000

c=20000
d=3000

e=(a+c)-(b+d)

e
# Out:
# 25000

# %%
ram_salary=10000
ram_expenses=2000

sham_salary=20000
sham_expenses=3000

total_savings = (ram_salary+sham_salary)-(ram_expenses+sham_expenses)

# %%
print(total_savings)
# Out:
# 25000

# %%
#we cannot use the key words as variable names

# %%
#alphanumeric characters '_' (underscore)

# %%
#4 star hotel, revenue is 400, 5 star hotel revenue 500, 3 star hotel have revenue 200. 
#Find the total revenue of the city per day.

# %%
a=400
b=500
c=200

d=a+b+c

# %%
d
# Out:
# 1100

# %%
#revenue generated by a 4 star hotel per day.
star_4_revenue=400

#revenue generated by a 5 star hotel per day.
star_5_revenue=500

#revenue generated by a 3 star hotel per day.
star_3_revenue=200

#Total revenue generated by these hotels.
revenue_per_day = star_3_revenue + star_4_revenue + star_5_revenue

# %%
a=400
b=500
c=200

# %%
x,y = 5, 20

# %%
x,y,z ,m, n, o = 5, 10,15,25,40,48

# %%
o
# Out:
# 48

# %%
y
# Out:
# 10

# %%
star_5_revenue, star_4_revenue, star_3_revenue = 500, 400, 200

revenue_per_day = star_3_revenue + star_4_revenue + star_5_revenue

# %%
print(revenue_per_day)
# Out:
# 1100

# %%
Ram_Salary = 400
# Out:
#   File "<ipython-input-74-0b2e1ba92cd9>", line 1
#     ram Salary = 400
#         ^
# SyntaxError: invalid syntax

# %%
RS=ram_slary=10000

# %%
ram_slary
# Out:
# 10000
